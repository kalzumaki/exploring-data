# %% [markdown]
# # CODE 5-9
#
# ## BOX PLOT

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/cars.csv')
dist = df['dist']
dist.plot.box(title='Breaking Distance')
plt.show()
