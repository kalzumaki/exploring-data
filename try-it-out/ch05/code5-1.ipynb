# %% [markdown]
# # TRY IT OUT (Part 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

hobby = pd.Series(['climbing','fishing','golf','swimming', 'climbing', 'climbing', 'fishing', 'swimming', 'climbing', 'fishing', 'swimming', 'golf'])

hobby
# Out:
# 0     climbing
# 1      fishing
# 2         golf
# 3     swimming
# 4     climbing
# 5     climbing
# 6      fishing
# 7     swimming
# 8     climbing
# 9      fishing
# 10    swimming
# 11        golf
# dtype: object

# %%
# create a frequency distribution table by hobby
hobby.value_counts().plot(kind='bar', xlabel='Hobby', ylabel='Frequency', rot=30)
# Out:
# <Axes: xlabel='Hobby', ylabel='Frequency'>

# %%
fig, axes = plt.subplots(ncols=2)

hobby.value_counts().plot(kind='bar', ax=axes[0], rot=30, title='Bar Graph Visualization')
hobby.value_counts().plot(kind='pie', ax=axes[1], autopct='%1.1f%%', ylabel='', title='Pie Chart Visualization')

plt.show()
